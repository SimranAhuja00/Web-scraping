# %%
import requests

# %%
result = requests.get('https://en.wikipedia.org/wiki/Taylor_Swift')

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Taylor Swift - Wikipedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclie
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %% [markdown]
# ##Grabbing a Page Title

# %%
soup.select('title')
# Out:
# [<title>Taylor Swift - Wikipedia</title>]

# %%
soup.select('title')[0]
# Out:
# <title>Taylor Swift - Wikipedia</title>

# %%
soup.select('title')[0].getText()
# Out:
# 'Taylor Swift - Wikipedia'

# %%
soup.select('p b')
# Out:
# [<b>Taylor Alison Swift</b>]

# %%
soup.select('b')
# Out:
# [<b>Musical career</b>,
#  <b>Taylor Alison Swift</b>,
#  <b><a href="#cite_ref-93">^</a></b>,
#  <b><a href="#cite_ref-154">^</a></b>,
#  <b><a href="#cite_ref-182">^</a></b>,
#  <b><a href="#cite_ref-203">^</a></b>,
#  <b><a href="#cite_ref-Newsround-2020_1-0">^</a></b>,
#  <b><a href="#cite_ref-Sutherland-2015_2-0">^</a></b>,
#  <b><a href="#cite_ref-3">^</a></b>,
#  <b>a</b>,
#  <b>b</b>,
#  <b><a href="#cite_ref-5">^</a></b>,
#  <b><a href="#cite_ref-6">^</a></b>,
#  <b><a href="#cite_ref-7">^</a></b>,
#  <b><a href="#cite_ref-8">^</a></b>,
#  <b><a href="#cite_ref-9">^</a></b>,
#  <b><a href="#cite_ref-10">^</a></b>,
#  <b>a</b>,
#  <b>b</b>,
#  <b>c</b>,
#  <b>d</b>,
#  <b>e</b>,
#  <b>f</b>,
#  <b>g</b>,
#  <b>h</b>,
#  <b><a href="#cite_ref-12">^</a></b>,
#  <b><a href="#cite_ref-13">^</a></b>,
#  <b><a href="#cite_ref-14">^</a></b>,
#  <b><a href="#cite_ref-readingeagle1_15-0">^</a></b>,
#  <b><a href="#cite_ref-16">^</a></b>,
#  <b><a href="#cite_ref-17">^</a></b>,
# ...

# %% [markdown]
# ##Grabbing a Class

# %%
soup.select('.mw-headline')
# Out:
# [<span class="mw-headline" id="Life_and_career">Life and career</span>,
#  <span class="mw-headline" id="Early_life">Early life</span>,
#  <span class="mw-headline" id="2004–2008:_Career_beginnings_and_first_album">2004–2008: Career beginnings and first album</span>,
#  <span class="mw-headline" id="2008–2010:_Fearless">2008–2010: <i>Fearless</i></span>,
#  <span class="mw-headline" id="2010–2014:_Speak_Now_and_Red">2010–2014: <i>Speak Now</i> and <i>Red</i></span>,
#  <span class="mw-headline" id="2014–2018:_1989_and_Reputation">2014–2018: <i>1989</i> and <i>Reputation</i></span>,
#  <span class="mw-headline" id="2018–2020:_Lover,_Folklore,_and_Evermore">2018–2020: <i>Lover</i>, <i>Folklore</i>, and <i>Evermore</i></span>,
#  <span class="mw-headline" id="2021–present:_Re-recordings_and_Midnights">2021–present: Re-recordings and <i>Midnights</i></span>,
#  <span class="mw-headline" id="Artistry">Artistry</span>,
#  <span class="mw-headline" id="Influences">Influences</span>,
# ...

# %%
for item in soup.select('.mw-headline'):
  print(item.text)
# Out:
# Life and career
# Early life
# 2004–2008: Career beginnings and first album
# 2008–2010: Fearless
# 2010–2014: Speak Now and Red
# 2014–2018: 1989 and Reputation
# 2018–2020: Lover, Folklore, and Evermore
# 2021–present: Re-recordings and Midnights
# Artistry
# Influences
# Music style
# Voice
# Songwriting
# Video and film
# Accolades and achievements
# Cultural status
# Legacy
# Public image
# Entrepreneurship
# Politics
# Wealth and philanthropy
# Discography
# Studio albums
# Re-recorded albums
# Filmography
# Tours
# See also
# Footnotes
# References
# Cited literature
# External links
